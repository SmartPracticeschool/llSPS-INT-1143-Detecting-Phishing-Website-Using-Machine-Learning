# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ravit\\Desktop\\Project'

# %%
os.chdir("C:/Users/ravit/Desktop/Project")
os.getcwd()
# Out:
# 'C:\\Users\\ravit\\Desktop\\Project'

# %%
import numpy as np
import pandas as pd
data1=pd.read_csv("dataset.csv")
data1
# Out:
#        index  having_IPhaving_IP_Address  URLURL_Length  Shortining_Service  \
# 0          1                          -1              1                   1
# 1          2                           1              1                   1
# 2          3                           1              0                   1
# 3          4                           1              0                   1
# 4          5                           1              0                  -1
# ...      ...                         ...            ...                 ...
# 11050  11051                           1             -1                   1
# 11051  11052                          -1              1                   1
# 11052  11053                           1             -1                   1
# 11053  11054                          -1             -1                   1
# 11054  11055                          -1             -1                   1
#
# ...

# %%
data1.describe()
# Out:
#               index  having_IPhaving_IP_Address  URLURL_Length  \
# count  11055.000000                11055.000000   11055.000000
# mean    5528.000000                    0.313795      -0.633198
# std     3191.447947                    0.949534       0.766095
# min        1.000000                   -1.000000      -1.000000
# 25%     2764.500000                   -1.000000      -1.000000
# 50%     5528.000000                    1.000000      -1.000000
# 75%     8291.500000                    1.000000      -1.000000
# max    11055.000000                    1.000000       1.000000
#
#        Shortining_Service  having_At_Symbol  double_slash_redirecting  \
# count        11055.000000      11055.000000              11055.000000
# mean             0.738761          0.700588                  0.741474
# std              0.673998          0.713598                  0.671011
# min             -1.000000         -1.000000                 -1.000000
# ...

# %%
data1.cov()
# Out:
#                                     index  having_IPhaving_IP_Address  \
# index                        1.018534e+07                -1176.749593
# having_IPhaving_IP_Address  -1.176750e+03                    0.901614
# URLURL_Length                1.492690e+01                   -0.038125
# Shortining_Service          -1.351040e+01                    0.258209
# having_At_Symbol            -3.859716e+02                    0.107532
# double_slash_redirecting    -7.201375e+00                    0.253196
# Prefix_Suffix               -1.588583e+01                   -0.003385
# having_Sub_Domain            6.107582e+02                   -0.062679
# SSLfinal_State              -1.944744e+01                    0.061836
# Domain_registeration_length -3.545685e+00                   -0.020331
# Favicon                      1.810349e+01                    0.064270
# port                         3.621856e+00                    0.039681
# ...

# %%
data1.corr()
# Out:
#                                 index  having_IPhaving_IP_Address  \
# index                        1.000000                   -0.388317
# having_IPhaving_IP_Address  -0.388317                    1.000000
# URLURL_Length                0.006105                   -0.052411
# Shortining_Service          -0.006281                    0.403461
# having_At_Symbol            -0.169478                    0.158699
# double_slash_redirecting    -0.003363                    0.397389
# Prefix_Suffix               -0.007340                   -0.005257
# having_Sub_Domain            0.234091                   -0.080745
# SSLfinal_State              -0.006682                    0.071414
# Domain_registeration_length -0.001180                   -0.022739
# Favicon                      0.007293                    0.087025
# port                         0.001656                    0.060979
# HTTPS_token                  0.002916                    0.363534
# ...

# %%
data1.head()
# Out:
#    index  having_IPhaving_IP_Address  URLURL_Length  Shortining_Service  \
# 0      1                          -1              1                   1
# 1      2                           1              1                   1
# 2      3                           1              0                   1
# 3      4                           1              0                   1
# 4      5                           1              0                  -1
#
#    having_At_Symbol  double_slash_redirecting  Prefix_Suffix  \
# 0                 1                        -1             -1
# 1                 1                         1             -1
# 2                 1                         1             -1
# 3                 1                         1             -1
# 4                 1                         1             -1
#
#    having_Sub_Domain  SSLfinal_State  Domain_registeration_length  ...  \
# 0                 -1              -1                           -1  ...
# ...

# %%
data1.columns
# Out:
# Index(['index', 'having_IPhaving_IP_Address', 'URLURL_Length',
#        'Shortining_Service', 'having_At_Symbol', 'double_slash_redirecting',
#        'Prefix_Suffix', 'having_Sub_Domain', 'SSLfinal_State',
#        'Domain_registeration_length', 'Favicon', 'port', 'HTTPS_token',
#        'Request_URL', 'URL_of_Anchor', 'Links_in_tags', 'SFH',
#        'Submitting_to_email', 'Abnormal_URL', 'Redirect', 'on_mouseover',
#        'RightClick', 'popUpWidnow', 'Iframe', 'age_of_domain', 'DNSRecord',
#        'web_traffic', 'Page_Rank', 'Google_Index', 'Links_pointing_to_page',
#        'Statistical_report', 'Result'],
#       dtype='object')

# %%
data1.tail()
# Out:
#        index  having_IPhaving_IP_Address  URLURL_Length  Shortining_Service  \
# 11050  11051                           1             -1                   1
# 11051  11052                          -1              1                   1
# 11052  11053                           1             -1                   1
# 11053  11054                          -1             -1                   1
# 11054  11055                          -1             -1                   1
#
#        having_At_Symbol  double_slash_redirecting  Prefix_Suffix  \
# 11050                -1                         1              1
# 11051                -1                        -1             -1
# 11052                 1                         1             -1
# 11053                 1                         1             -1
# 11054                 1                         1             -1
#
#        having_Sub_Domain  SSLfinal_State  Domain_registeration_length  ...  \
# ...

# %%
data1.dtypes
# Out:
# index                          int64
# having_IPhaving_IP_Address     int64
# URLURL_Length                  int64
# Shortining_Service             int64
# having_At_Symbol               int64
# double_slash_redirecting       int64
# Prefix_Suffix                  int64
# having_Sub_Domain              int64
# SSLfinal_State                 int64
# Domain_registeration_length    int64
# Favicon                        int64
# port                           int64
# HTTPS_token                    int64
# Request_URL                    int64
# URL_of_Anchor                  int64
# Links_in_tags                  int64
# SFH                            int64
# Submitting_to_email            int64
# Abnormal_URL                   int64
# Redirect                       int64
# on_mouseover                   int64
# RightClick                     int64
# popUpWidnow                    int64
# Iframe                         int64
# age_of_domain                  int64
# ...

# %%
data1['having_IPhaving_IP_Address'].unique()
# Out:
# array([-1,  1], dtype=int64)

# %%
data1['having_Sub_Domain'].unique()
# Out:
# array([-1,  0,  1], dtype=int64)

# %%
data1['Statistical_report'].unique()
# Out:
# array([-1,  1], dtype=int64)

# %%
data1['Result'].unique()
# Out:
# array([-1,  1], dtype=int64)

# %%
data1.pivot_table(data1,index=['Result'])
# Out:
#         Abnormal_URL  DNSRecord  Domain_registeration_length   Favicon  \
# Result
# -1          0.753369   0.298489                    -0.098408  0.628828
#  1          0.667046   0.439662                    -0.526393  0.628390
#
#         Google_Index  HTTPS_token   Iframe  Links_in_tags  \
# Result
# -1          0.621478     0.708044  0.81911      -0.330747
#  1          0.801202     0.648855  0.81517       0.050999
#
#         Links_pointing_to_page  Page_Rank  ...  age_of_domain  \
# Result                                     ...
# -1                    0.323193  -0.586362  ...      -0.074724
#  1                    0.360565  -0.401981  ...       0.169401
#
#         double_slash_redirecting  having_At_Symbol  \
# Result
# -1                      0.770519          0.658228
#  1                      0.718369          0.734286
#
#         having_IPhaving_IP_Address  having_Sub_Domain        index  \
# Result
# -1                        0.213557          -0.209473  5524.501837
# ...
